# %% [markdown]
# <!-- ========================= -->
# <!--  NOTEBOOK HEADER TEMPLATE -->
# <!-- ========================= -->
#
# <!-- Título principal do notebook -->
# <h1 style="color:#1f77b4; text-align:left; font-size:40px; margin-bottom:0;">
#      Telco Customer Churn Prediction Project
# </h1>
#
# <!-- Subtítulo -->
# <h3 style="color:#555; text-align:left; margin-top:5px;">
#     Diana Gomes- nº mecanográfico xxxxxxxx<br>
#     Sara Góis - nº mecanográfico xxxxxxxx<br>
#     Tiago Francos - nº mecanográfico xxxxxxxx <br>
#     Sérgio Patinha - nº mecanográfico xxxxxxxx<br>
# </h3>
#
# <!-- Informação de autor / data -->
# <p style="text-align:left; color:#777; font-size:13px;">
#     <b>2025-12-05</b>
# </p>

# %% [markdown]
# <h1 style="color:#1f77b4; text-align:left; font-size:40px;">
#     Business Understanding
# </h1>
#
# <h3 style="color:#555; text-align:left;">
#     Description, Objectives, Impact and Metrics/Kpi's
# </h3>
#
#
# <h2 style="color:#1f77b4; border-bottom: 3px solid #1f77b4; padding-bottom:4px;">
# </h2>

# %% [markdown]
# # 1: Description:
#
# Group project for the course Big Data Bootcamp — Postgraduate Program in Enterprise Data Science & Analytics.
# Group EDSB25_20
# Members:
# -     Diana Gomes nº mec: 20240829
# -     Sara Góis nº mec: 20242129
# -     Sérgio Patinha nº mec: 20241149
# -     Tiago Franco nº mec: 20242038
#
# # 2: Objective
#
# Predict customer churn for a telecommunications company, identifying the main factors that influence customer departure and proposing retention strategies.
#
#
# # 3: Structure
#
# - `data/` — Raw and procedd data
# - `notebooks/` — notebooks of analysis and modeling
#
#       - 002_data_loading.ipynb | Raw data access
#       Import libraries, define paths, load raw files, quick data sanity check (shapes, missing files).
#
#          Dataset Overview:
#          The Telco churn project uses five datasets provided by the telecom company:
#                Demographics – customer-level attributes (such as gender, age, marital status).
#                Location – customer’s geographical data (state, city, ZIP).
#                Services – subscribed telecom products (phone, internet, streaming).
#                Status – account-level information including churn flag and reason.
#                Population – ZIP-level population counts for contextual enrichment.
#          Each of the first four datasets contains 7,043 unique customers identified by Customer ID.
#          The Population dataset includes 1,671 ZIP codes, which can be linked to customers via their location data.
#
#       - 003_EDA.ipynb | Insights
#       Summaries, distributions, correlations, churn patterns, first insights.
#
#       - 004_Data_Preparation_and_Cleaning.ipynb | Data preparation
#       Merge datasets, normalize IDs, handle missing values, fix datatypes, rename columns, remove duplicates.
#
#       - 005_modeling.ipynb | Model training
#       Model Selection, Train and validation, hyperparameters, model comparison, model interpretation.
#
#       - 006_model_evaluation.ipynb | Model Evaluation
#       Test with non used data, Evaluation metrics, Overfitting and Model interpretation
#
#       - 007_Deploy.ipynb |
#       ???? Hugging face
#
# - `src/` — modularized code (ETL, modeling, explainability)
# - `app/` — interactive application for deployment (Gradio/Streamlit) ← Hugging Face
# - `presentation/` — slides and presentation materials

# %% [markdown]
# <!-- MODELO: Secção principal numerada -->
# <!--
# <h2 style="background-color:#1f77b4; color:white; padding:10px; border-radius:6px;">
#     X. Nome da Secção
# </h2>
# -->
#
# <!-- MODELO: Secção com linha colorida -->
# <!--
# <h2 style="color:#ff7f0e; border-bottom: 3px solid #ff7f0e; padding-bottom:4px;">
#     X. Nome da Secção
# </h2>
# -->
#
# <!-- MODELO: Subsecção -->
# <!--
# <h3 style="color:#2ca02c; margin-top:10px;">
#     X.Y Nome da Subsecção
# </h3>
# -->
#
# <!-- MODELO: Caixa de Nota -->
# <!--
# <div style="border-left: 5px solid #1f77b4; padding:10px; background-color:#f5f9ff; margin:15px 0;">
#     <b>Nota:</b> Texto da nota.
# </div>
# -->

# %% [markdown]
# <!-- MODELO: Secção principal numerada -->
# <!--
# <h2 style="background-color:#1f77b4; color:white; padding:10px; border-radius:6px;">
#     X. Nome da Secção
# </h2>
# -->
#
# <!-- MODELO: Secção com linha colorida -->
# <!--
# <h2 style="color:#ff7f0e; border-bottom: 3px solid #ff7f0e; padding-bottom:4px;">
#     X. Nome da Secção
# </h2>
# -->
#
# <!-- MODELO: Subsecção -->
# <!--
# <h3 style="color:#2ca02c; margin-top:10px;">
#     X.Y Nome da Subsecção
# </h3>
# -->
#
# <!-- MODELO: Caixa de Nota -->
# <!--
# <div style="border-left: 5px solid #1f77b4; padding:10px; background-color:#f5f9ff; margin:15px 0;">
#     <b>Nota:</b> Texto da nota.
# </div>
# -->
