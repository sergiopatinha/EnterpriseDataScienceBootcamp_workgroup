# %% [markdown]
# # **Hipotese 1**

# %% [markdown]
# <h1 style="color:#1f77b4; text-align:left; font-size:40px;">
#     1 - Business Understanding
# </h1>
#
# <h3 style="color:#555; text-align:left;">
#     Description, Objectives, Impact and Metrics/Kpi's
# </h3>
#
# <h2 style="color:#1f77b4; border-bottom: 3px solid #1f77b4; padding-bottom:4px;">
# </h2>

# %% [markdown]
# # 1: Introduction
# ## 1.1: Description
# ### 1.1.1: Description
# #### 1.1.1.1: Description

# %% [markdown]
# # **Hipotese 2:**

# %% [markdown]
# <!-- ========================= -->
# <!--  NOTEBOOK HEADER TEMPLATE -->
# <!-- ========================= -->
#
# <!-- Título principal do notebook -->
# <h1 style="color:#1f77b4; text-align:center; font-size:40px; margin-bottom:0;">
#      Data Science Project
# </h1>
#
# <!-- Subtítulo -->
# <h3 style="color:#555; text-align:center; margin-top:5px;">
#     Dataset: <i>nome_do_dataset.csv</i>
# </h3>
#
# <!-- Informação de autor / data -->
# <p style="text-align:center; color:#777; font-size:13px;">
#     Autor: <b>O Teu Nome</b> &nbsp;•&nbsp; Data: <b>2025-11-23</b>
# </p>
#
# <hr style="border: none; border-top: 2px solid #ddd; margin: 20px 0;">
#
#
# <!-- ========================= -->
# <!--  ÍNDICE (opcional)        -->
# <!-- ========================= -->
#
# <h2 style="color:#ff7f0e;"> Índice</h2>
#
# - [1. Introdução](#intro)
# - [2. Importação de Dados](#import)
# - [3. Análise Exploratória](#eda)
# - [4. Pré-processamento](#prep)
# - [5. Modelação](#model)
# - [6. Avaliação](#eval)
# - [7. Conclusões](#conclusions)
#
# <hr style="border: none; border-top: 1px solid #eee; margin: 20px 0;">
#
#
# <!-- ========================= -->
# <!--  ESTILOS DE TÍTULOS       -->
# <!-- (copiar e usar abaixo)    -->
# <!-- ========================= -->
#
# <!-- 1. Secção principal -->
# <a id="intro"></a>
# <h2 style="background-color:#1f77b4; color:white; padding:10px; border-radius:6px;">
#     1. Introdução
# </h2>
#
# <!-- 2. Secção com linha colorida -->
# <a id="import"></a>
# <h2 style="color:#ff7f0e; border-bottom: 3px solid #ff7f0e; padding-bottom:4px;">
#     2. Importação de Dados
# </h2>
#
# <!-- 3. Secção com ícone -->
# <a id="eda"></a>
# <h2 style="color:#2ca02c;">
#     3. Análise Exploratória de Dados (EDA)
# </h2>
#
# <!-- 4. Subsecção menor -->
# <h3 style="color:#2ca02c; margin-top:10px;">
#     3.1 Estatísticas Descritivas
# </h3>
#
# <!-- 5. Outra subsecção -->
# <h3 style="color:#2ca02c; margin-top:10px;">
#     3.2 Distribuições das Variáveis
# </h3>
#
# <!-- EXEMPLO de caixas de destaque (nota / aviso / dica) -->
#
# <!-- Caixa de Nota -->
# <div style="border-left: 5px solid #1f77b4; padding:10px; background-color:#f5f9ff; margin:15px 0;">
#     <b>Nota:</b> Adiciona aqui alguma explicação importante sobre o objetivo do notebook.
# </div>
#
# <!-- Caixa de Aviso -->
# <div style="border-left: 5px solid #d62728; padding:10px; background-color:#fff5f5; margin:15px 0;">
#     <b>Aviso:</b> Verifica sempre se o caminho para o ficheiro de dados está correto antes de correr o notebook.
# </div>
#
# <!-- Caixa de Dica -->
# <div style="border-left: 5px solid #2ca02c; padding:10px; background-color:#f3fff5; margin:15px 0;">
#     <b>Dica:</b> Usa funções reutilizáveis no teu código para manter o notebook mais limpo.
# </div>
#
# <!-- ========================= -->
# <!--  MODELOS PARA REUTILIZAR  -->
# <!--  (copiar para outras sec.)-->
# <!-- ========================= -->
#
# <!-- MODELO: Secção principal numerada -->
# <!--
# <h2 style="background-color:#1f77b4; color:white; padding:10px; border-radius:6px;">
#     X. Nome da Secção
# </h2>
# -->
#
# <!-- MODELO: Secção com linha colorida -->
# <!--
# <h2 style="color:#ff7f0e; border-bottom: 3px solid #ff7f0e; padding-bottom:4px;">
#     X. Nome da Secção
# </h2>
# -->
#
# <!-- MODELO: Subsecção -->
# <!--
# <h3 style="color:#2ca02c; margin-top:10px;">
#     X.Y Nome da Subsecção
# </h3>
# -->
#
# <!-- MODELO: Caixa de Nota -->
# <!--
# <div style="border-left: 5px solid #1f77b4; padding:10px; background-color:#f5f9ff; margin:15px 0;">
#     <b>Nota:</b> Texto da nota.
# </div>
# -->
