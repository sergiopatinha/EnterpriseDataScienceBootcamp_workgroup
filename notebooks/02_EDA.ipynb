# %% [markdown]
# # Summary — Next Steps After EDA (Pre-Modeling Preparation)
# Key Actions:
# - Handle Categorical Variables
#     - Convert all Yes/No flags (e.g., demo_married, svc_paperless_billing) to binary (1/0).
#     - One-hot encode nominal variables such as svc_offer, svc_payment_method, svc_internet_type.
#     - Ordinal-encode ordered features like svc_contract (e.g., Month-to-month = 0, One-year = 1, Two-year = 2).
#     - Drop leakage variables: st_churn_score, st_customer_status, st_churn_category, st_churn_reason.
#     - Exclude identifiers (loc_zip_code, loc_city) or aggregate them at a regional level if useful.
# - Prepare Numeric Variables
#     - Scale or normalize numeric features (StandardScaler or MinMaxScaler) to ensure comparability.
#     - Apply log transformations to highly skewed monetary variables (st_cltv, svc_total_revenue, etc.).
#     - Remove redundant variables if highly correlated (e.g., total vs. component charges).
#     - Optionally bin continuous variables for interpretability (e.g., age or tenure groups).
# - Define Target Variable
#     - Use st_churn_label as the binary target (1 = Yes, 0 = No).
#     - Drop duplicate target columns (st_churn_value).
# - Finalize Feature Set
#     - Separate final features into:
#         - num_features → scaled numerical variables
#         - cat_features → encoded categorical variables
#     - Save the cleaned and encoded dataset as processed/telco_model_ready.parquet.
